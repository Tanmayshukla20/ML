# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanmayshukla20/ML/blob/main/3_working_with_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
#Then requests library takes requests api to give data
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 30.1019,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.712,
#    'vote_count': 28670},
#   {'adult': False,
#    'backdrop_path': '/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response. json()['results'] #taking out the particular list named results from the file
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 30.1019,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.712,
#   'vote_count': 28670},
#  {'adult': False,
#   'backdrop_path': '/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
  #to conver the data into pandas data frame
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1   False  /htuuuEwAvDVECMpb0ltLLyZyDDt.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg              [18]     389
# 5   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg   [16, 10751, 14]     129
# 6   False   /enNubozHn9pXi0ycTVYUWfpHZm.jpg  [18, 28, 80, 53]     155
# 7   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 8   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]     497
# 9   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 10  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg      [12, 14, 28]     122
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg  [53, 80, 35, 18]     680
# ...

# %%
df=pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
df.head() #selecting the particular columns and diplaying top 5
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     30.1019
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     27.6438
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     15.8254
# 3  The true story of how businessman Oskar Schind...   1993-12-15     13.6979
# 4  The defense and the prosecution have rested an...   1957-04-10     15.2506
#
#    vote_average  vote_count
# 0         8.712       28670
# 1         8.686       21699
# 2         8.571       13098
# 3         8.566       16613
# 4         8.549        9306

# %%
df = pd.DataFrame()
df #creating an empty dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#loop for printing the same information as above for movies on remaining 428 pages as the json file has 428 pages
for i in range (1,429):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))  #here page no. is equal to i at that iteration represented by format(i)
  temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
  df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.head() #displaying top 5
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     30.1019
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     27.6438
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     15.8254
# 3  The true story of how businessman Oskar Schind...   1993-12-15     13.6979
# 4  The defense and the prosecution have rested an...   1957-04-10     15.2506
#
#    vote_average  vote_count
# 0         8.712       28670
# 1         8.686       21699
# 2         8.571       13098
# 3         8.566       16613
# 4         8.549        9306

# %%
df #displaying the whole data
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  736500           Retirement Home
# 8556  513409           Earthquake Bird
# 8557  362637         Opposites Attract
# 8558   13006              Split Second
# 8559    1995   Lara Croft: Tomb Raider
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.to_csv('movies.csv') #converting data frame int csv which you may post on kaggle
