# %%
#using the titanic dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (0.0.dev0)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (2.3.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: minify-html>=0.15.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (0.16.4)
# Requirement already satisfied: filetype>=1.0.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: typing_extensions>=4.14.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from typeguard<5,>=3->ydata-profiling) (4.14.1)
# Requirement already satisfied: attrs>=19.3.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv('train.csv')

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file("output.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 232.35it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install numpy==1.26.4
# Out:
# Requirement already satisfied: numpy==1.26.4 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (1.26.4)

# %%
# !pip install git+https://github.com/ydataai/ydata-profiling.git
# Out:
# Collecting git+https://github.com/ydataai/ydata-profiling.git
#   Cloning https://github.com/ydataai/ydata-profiling.git to /private/var/folders/jc/gkgdlrpj67v2z8qk8g1sjt4r0000gn/T/pip-req-build-s9us3_zm
#   Running command git clone --filter=blob:none --quiet https://github.com/ydataai/ydata-profiling.git /private/var/folders/jc/gkgdlrpj67v2z8qk8g1sjt4r0000gn/T/pip-req-build-s9us3_zm
#   Resolved https://github.com/ydataai/ydata-profiling.git to commit de97bd4a50ed49ef0c7aad452c9f5fc389cd2d48
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (2.3.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==0.0.dev0) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.26.4)
# Requirement already satisfied: minify-html>=0.15.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.16.4)
# Requirement already satisfied: filetype>=1.0.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.61.0)
# Requirement already satisfied: PyWavelets in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (1.9.0)
# Requirement already satisfied: pillow in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==0.0.dev0) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from numba<=0.61,>=0.56.0->ydata-profiling==0.0.dev0) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling==0.0.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling==0.0.dev0) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from phik<0.13,>=0.11.1->ydata-profiling==0.0.dev0) (1.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (1.0.1)
# Requirement already satisfied: typing_extensions>=4.14.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from typeguard<5,>=3->ydata-profiling==0.0.dev0) (4.14.1)
# Requirement already satisfied: attrs>=19.3.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==0.0.dev0) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==0.0.dev0) (3.5)
# Requirement already satisfied: puremagic in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==0.0.dev0) (1.30)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==0.0.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==0.0.dev0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==0.0.dev0) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/tanmayshukla/Desktop/housepricepredictor/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (1.17.0)

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2559.06it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
