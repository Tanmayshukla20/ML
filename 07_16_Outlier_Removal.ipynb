# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanmayshukla20/ML/blob/main/16_Outlier_Removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Outlier removal using Z score:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.shape
# Out:
# (1000, 3)

# %%
 df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 490  7.34                  32.0       0
# 193  6.31                  14.0       0
# 64   6.98                  52.0       1
# 651  6.57                  39.0       1
# 531  7.00                  81.0       1

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])

plt.show()
# Out:
# /tmp/ipython-input-3792736820.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# /tmp/ipython-input-3792736820.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %%
#here 'cgpa' is normally distributed but 'placement_exam_marks' is skewed so Z score has to be applied on the 'cgpa' column only.

# %%
df['placement_exam_marks'].skew()
# Out:
# np.float64(0.8356419499466834)

# %%
print("Mean value of cgpa",df['cgpa'].mean())
print("Std value of cgpa",df['cgpa'].std())
print("Min value of cgpa",df['cgpa'].min())
print("Max value of cgpa",df['cgpa'].max())
# Out:
# Mean value of cgpa 6.96124
# Std value of cgpa 0.6158978751323894
# Min value of cgpa 4.89
# Max value of cgpa 9.12

# %%
# Finding the boundary values
print("Highest allowed",df['cgpa'].mean() + 3*df['cgpa'].std())
print("Lowest allowed",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 8.808933625397168
# Lowest allowed 5.113546374602832

# %%
# Finding the outliers
df[(df['cgpa'] > 8.80) | (df['cgpa'] < 5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %% [markdown]
# # Trimming:

# %%
# Trimming

new_df = df[(df['cgpa'] < 8.80) & (df['cgpa'] > 5.11)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 991  7.04                  57.0       0
# 992  6.26                  12.0       0
# 993  6.73                  21.0       1
# 994  6.48                  63.0       0
# 998  8.62                  46.0       1
#
# [995 rows x 3 columns]

# %%
# Approach 2

# Calculating the Zscore

df['cgpa_zscore'] = (df['cgpa'] - df['cgpa'].mean())/df['cgpa'].std()

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed  cgpa_zscore
# 0  7.19                  26.0       1     0.371425
# 1  7.46                  38.0       1     0.809810
# 2  7.54                  40.0       1     0.939701
# 3  6.42                   8.0       1    -0.878782
# 4  7.23                  17.0       0     0.436371

# %%
df[df['cgpa_zscore'] > 3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062

# %%
df[df['cgpa_zscore'] < -3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -3.314251
# 997  4.89                  34.0       0    -3.362960
# 999  4.90                  10.0       1    -3.346724

# %%
df[(df['cgpa_zscore'] > 3) | (df['cgpa_zscore'] < -3)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -3.314251
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062
# 997  4.89                  34.0       0    -3.362960
# 999  4.90                  10.0       1    -3.346724

# %%
# Trimming
new_df = df[(df['cgpa_zscore'] < 3) & (df['cgpa_zscore'] > -3)]

# %%
new_df
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                  26.0       1     0.371425
# 1    7.46                  38.0       1     0.809810
# 2    7.54                  40.0       1     0.939701
# 3    6.42                   8.0       1    -0.878782
# 4    7.23                  17.0       0     0.436371
# ..    ...                   ...     ...          ...
# 991  7.04                  57.0       0     0.127878
# 992  6.26                  12.0       0    -1.138565
# 993  6.73                  21.0       1    -0.375452
# 994  6.48                  63.0       0    -0.781363
# 998  8.62                  46.0       1     2.693239
#
# [995 rows x 4 columns]

# %% [markdown]
# # Capping:

# %%
upper_limit = df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit = df['cgpa'].mean() - 3*df['cgpa'].std()

# %%
lower_limit
# Out:
# np.float64(5.113546374602832)

# %%
upper_limit
# Out:
# np.float64(8.808933625397168)

# %%
df['cgpa'] = np.where(
    df['cgpa']>upper_limit,
    upper_limit,
    np.where(
        df['cgpa']<lower_limit,
        lower_limit,
        df['cgpa']
    )
)

# %%
df.shape
# Out:
# (1000, 4)

# %%
df['cgpa'].describe()
# Out:
# count    1000.000000
# mean        6.961499
# std         0.612688
# min         5.113546
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         8.808934
# Name: cgpa, dtype: float64

# %% [markdown]
# # **Outlier romoval using IQR**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])

plt.show()
# Out:
# /tmp/ipython-input-3792736820.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# /tmp/ipython-input-3792736820.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %%
#Here we see that cgpa is normally distributed but placement_exam_marks are skewed so we will apply IQR on placement_exam_marks

# %%
df['placement_exam_marks'].skew() #It is right skewed
# Out:
# np.float64(0.8356419499466834)

# %%
df['cgpa'].skew()
# Out:
# np.float64(-0.014529938929314918)

# %%
df['placement_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(df['placement_exam_marks'])
# Out:
# <Axes: ylabel='placement_exam_marks'>

# %%
# Finding the IQR
percentile25 = df['placement_exam_marks'].quantile(0.25)
percentile75 = df['placement_exam_marks'].quantile(0.75)

# %%
percentile75
# Out:
# np.float64(44.0)

# %%
percentile25
# Out:
# np.float64(17.0)

# %%
iqr = percentile75 - percentile25
iqr
# Out:
# np.float64(27.0)

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 84.5
# Lower limit -23.5

# %% [markdown]
# # Finding Outliers

# %%
df[df['placement_exam_marks'] > upper_limit]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                  94.0       1
# 40   6.60                  86.0       1
# 61   7.51                  86.0       0
# 134  6.33                  93.0       0
# 162  7.80                  90.0       0
# 283  7.09                  87.0       0
# 290  8.38                  87.0       0
# 311  6.97                  87.0       1
# 324  6.64                  90.0       0
# 630  6.56                  96.0       1
# 685  6.05                  87.0       1
# 730  6.14                  90.0       1
# 771  7.31                  86.0       1
# 846  6.99                  97.0       0
# 917  5.95                 100.0       0

# %%
df[df['placement_exam_marks'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed]
# Index: []

# %% [markdown]
# # Trimming

# %%
new_df = df[df['placement_exam_marks'] < upper_limit]

# %%
new_df.shape
# Out:
# (985, 3)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df['placement_exam_marks'])

plt.show()
# Out:
# /tmp/ipython-input-3798459719.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# /tmp/ipython-input-3798459719.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['placement_exam_marks'])

# %% [markdown]
# # Capping

# %%
new_df_cap = df.copy()

new_df_cap['placement_exam_marks'] = np.where(
    new_df_cap['placement_exam_marks'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['placement_exam_marks'] < lower_limit,
        lower_limit,
        new_df_cap['placement_exam_marks']
    )
)

# %%
#np.where(condtion,true,false)

# %%
new_df_cap.shape
# Out:
# (1000, 3)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df_cap['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df_cap['placement_exam_marks'])

plt.show()
# Out:
# /tmp/ipython-input-3538926932.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# /tmp/ipython-input-3538926932.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df_cap['placement_exam_marks'])

# %% [markdown]
# # **Outlier detection using percentile**

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(df['Height'])
# Out:
# /tmp/ipython-input-3945773010.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
upper_limit = df['Height'].quantile(0.99)
upper_limit
# Out:
# np.float64(74.7857900583366)

# %%
lower_limit = df['Height'].quantile(0.01)
lower_limit
# Out:
# np.float64(58.13441158671655)

# %%
new_df = df[(df['Height'] <= 74.78) & (df['Height'] >= 58.13)]

# %%
new_df['Height'].describe()
# Out:
# count    9799.000000
# mean       66.363507
# std         3.644267
# min        58.134496
# 25%        63.577147
# 50%        66.317899
# 75%        69.119859
# max        74.767447
# Name: Height, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.distplot(new_df['Height'])
# Out:
# /tmp/ipython-input-1622920233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(new_df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
# Capping --> Winsorization
df['Height'] = np.where(df['Height'] >= upper_limit,
        upper_limit,
        np.where(df['Height'] <= lower_limit,
        lower_limit,
        df['Height']))

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
sns.distplot(df['Height'])
# Out:
# /tmp/ipython-input-3945773010.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>
